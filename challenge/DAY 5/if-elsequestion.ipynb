# %% [markdown]
# # 🟢 Basics — if/else
#
#
#
#
# # Check if a year is a leap year.
#
#
#
# # 🟡 Intermediate — for + if/else combined
#
#
#
#
# # Check if a number is an Armstrong number (e.g., 153 = 1³+5³+3³).

# %%
# Question 1
# Check if a number is positive, negative, or zero.

user = int(input("Enter the number :"))
if user> 0:
      print(f"{user} is positive number ")
elif user <0:
            print(f"{user} is Negative  number ")
else :
     print(f"{user} is zero ")

# %%
#Question 2
# Check if a number is even or odd.
user_input = int(input("Enter the number :"))
if user_input%2 == 0:
    print(f"{user_input} is Evenn Number ")
else :
    print(f"{user_input} is Odd Number ")

# %%
#Question 3
# Find the largest of three numbers.

user = int(input("Enter Any Three Numbers :"))
user1 = int(input("Enter Any Three Numbers :"))
user2 = int(input("Enter Any Three Numbers :"))
if user >= user1 and user >=user2:
    print(user)

elif user1 >= user2 and user1 >=user :
    print(user1)

elif user2 >= user and user2 >= user1 :
    print(user2)

# %%
#Question 4
# Grade calculator: take marks, print grade (A/B/C/F) using if-elif-else.

user = float(input("Enter your marks"))

if user >=  80:
    print("Grade A")
    
elif user >= 60 :
    print("Grade B")
elif user >= 50:
    print("Grade c")
else:
    print("Grade F")

# %%
#Question 5
# FizzBuzz: print numbers 1–100, but "Fizz" for multiples of 3, "Buzz" for multiples of 5, "FizzBuzz" for both.

for x in range (1,101):
    if x%3 == 0 and x % 5 == 0:
        print(f"{x} - FizzBuzz")
    elif x %3 == 0:
        print(f"{x} - Buzz")
    elif  x %5 == 0:
        print(f"{x} - Fizz")
    else :
        print(x)

# %%
#Question 6
# Print all prime numbers between 1 and N.

# %%
#Question 7
# Count vowels and consonants in a string using a loop.

# user = input("Enter you string: ")
count = 0
total = 0
for x in "programmming":
      
    if x in ['a', 'i','e','o','u']:
        count +=1
       
    else:
        total += 1
print(f"vowels : {count} ")
print(f"consonants : {total} ")

# %% [markdown]
# ## 💡 What changed (important logic upgrade)
#
# ### x.isalpha() → ignores spaces, numbers, symbols
#
# ### x.lower() → handles uppercase + lowercase
# Proper separation of vowel vs consonant

# %%
# QUestion 8
#  Count vowels and consonants in a string using a loop.
# but this time the string is give the user 

user = input("Ente the string :")

total =0 
count =0

for x in user:
    if x.isalpha():
     if x in ['a', 'i','e','o','u']:
        count +=1
       
     else:
        total += 1
print(f"vowels :  {count} ")
print(f"consonants : {total} ")

# %% [markdown]
# Order	Second Largest
# num2 < num1 < num3	num1
# num3 < num1 < num2	num1
# num1 < num2 < num3	num2
# num3 < num2 < num1	num2
# num1 < num3 < num2	num3
# num2 < num3 < num1	num3

# %%
# Question 9
# Find the second largest number in a list without using sort() or max().

num1 = int(input("Enter the Number :"))
num2 = int(input("Enter the Number :"))
num3 =int(input("Enter the Number :"))
if num1>num2 and num1<num3:
    print(num1)

elif num1>num3 and num1<num2:
    print(num1)

elif num2 >num1 and num2<num3:
    print(num2)
elif num2> num3  and num2<num1:
    print(num2)
elif num3 >num1 and num3<num2:
    print(num3)
elif num3>num2 and num3<num1:
    print(num3)
# Out:
# 30

# %%
#Question 10
# Check if a triangle is valid given three angles (should sum to 180).


num1 = int(input("Enter the first angle :"))
num2 = int(input("Enter the second angle :"))
num3 = int(input("Enter the third angle :"))

total= num1+num2+num3

if total == 180 and num1 > 0 and num2 > 0 and num3 > 0:
    print("valid triangle")
else :
    print("invalid triangle")
# Out:
# invalid triangle
