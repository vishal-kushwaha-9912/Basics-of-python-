# %% [markdown]
# ### 1. Built-in Function Question
#
# #### Take 5 numbers from the user and print:
#
# #### Maximum number using max()
# #### Minimum number using min()
# #### Sum using sum()
#
# #### Example Output
#
# #### Maximum = 45
# #### Minimum = 10
# #### Sum = 120

# %%
number = []

for x in range(5):

 num = int (input("Enter any five number :"))
 number.append(num)

print("Number =", number)
print ("Number =",max(number))
print ("Number =",min(number))
print ("Total number sum is :",sum(number))

# %% [markdown]
# ### 2. Built-in Function Question
#
# Create a list:
#
# numbers = [12, 5, 8, 20, 3]
#
# Use built-in functions to print:
#
# Length of list (len())
# Largest number (max())
# Smallest number (min())
# Sorted list (sorted())

# %%
number = [12 , 5, 8,20 ,3]

length  = (len(number))
largest = (max(number))
smallest = (min(number))
sorted_list = (sorted(number))

print("length" , length)
print("largest" , largest)
print("smallest" , smallest)
print("sortest list ",sorted_list)
# Out:
# length 5
# largest 20
# smallest 3
# sortest  [3, 5, 8, 12, 20]

# %% [markdown]
# ### 3. Math Module Question
#
# Import the math module and find:
#
# Square root of 144
# Factorial of 6
# Value of π (pi)

# %%
import math


number = math.sqrt(144)
fact = math.factorial(6)
value = math.pi
print( "square root is :" ,number)
print( "factorial is : ",fact)
print("value of pi :" , value)
# Out:
# square root is : 12.0
# factorial is :  720
# value of pi : 3.141592653589793

# %% [markdown]
# ### 4. Random Module Question
#
# Generate a random number between 1 and 100.
#
# Then print whether the number is:
#
# Even ,
# Odd

# %%
import random
number =random.randint(1,100)

print("random number : ", number) 

if number % 2 ==0:
     print("Even number ")
else :
    print ("ODD number ")
# Out:
# random number :  25
# ODD number

# %% [markdown]
# #### Generate a random number between 1 and 100 and print whether it is:
#
# Positive or Negative
# Even or Odd

# %%
import random
number =random.randint(-100,100)

print("The number is :", number )

if number >0:
    print ("Positive number ")
    if number % 2 == 0:
     print ("Even number ")
    else:
        print("Odd number ") 
elif number < 0:
    print ("Negative number ")    
else :
    print ("Zero")
# Out:
# The number is : 55
# Positive number
# Odd number
